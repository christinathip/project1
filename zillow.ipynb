# %%
# Import quandl to retrieve data
# Pandas and matplotlib standard imports for data analysis
import quandl
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Use Plotly for better graphs
import plotly.offline as plotly
import plotly.graph_objs as go
import plotly.graph_objects as go

# Offline Plotting
plotly.init_notebook_mode(connected=True)

# Put your api key here
quandl.ApiConfig.api_key = 'g3sVyGQgGrx_J1RV9E43'
mapbox_access_token = 'g3sVyGQgGrx_J1RV9E43'

# Start date and end date should be the same
start_date = '2010-07-31'
end_date = '2019-08-31'

greater_metro = ['M9','M31','M3','M33']
city = ['Atlanta', 'Austin','Chicago', 'Nashville']
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
c = 0
for m in greater_metro:    
    # Median Listing Price All Homes    
    MLPAH_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[c]+'_MLPAH', start_date=start_date, end_date=end_date))
    MLPAH_df.rename(columns = {"Value":"Median Listing Price: All Homes"}, inplace = True)
    # Median Listing Price Single Family Homes
    MLPSF_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[c]+'_MLPSF', start_date=start_date, end_date=end_date))
    MLPSF_df.rename(columns = {"Value":"Median Listing Price: Single Family"}, inplace = True)
    # Median Listing Price Condos
    MLPCC_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[c]+'_MLPCC', start_date=start_date, end_date=end_date))
    MLPCC_df.rename(columns = {"Value":"Median Listing Price: Condos"}, inplace = True)
    # Median Listing Price Merged 
    MLP_df = MLPAH_df.merge(MLPSF_df, on=["Date"]).merge(MLPCC_df,on=["Date"])
     
    # Median Rental Price All Homes
    MRPAH_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[c]+'_MLPCC', start_date=start_date, end_date=end_date))
    MRPAH_df.rename(columns = {"Value":"Median Rental: All Homes"}, inplace = True)
    # Median Rental Price Single Family Homes
    MRPSF_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[c]+'_MLPCC', start_date=start_date, end_date=end_date))
    MRPSF_df.rename(columns = {"Value":"Median Rental: Single Family"}, inplace = True)
    # Median Rental Price Condos
    MRPCC_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[c]+'_MLPCC', start_date=start_date, end_date=end_date))
    MRPCC_df.rename(columns = {"Value":"Median Rental: Condos"}, inplace = True)
    # Median Rental Price Merged
    MRP_df = MRPAH_df.merge(MRPSF_df, on=["Date"]).merge(MRPCC_df, on=["Date"])

    # Zillow Home Value Index All Homes
    ZHVIAH_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[c]+'_MLPCC', start_date=start_date, end_date=end_date))
    ZHVIAH_df.rename(columns = {"Value":"Zillow Home Value Index: All Homes"}, inplace = True)
    # Zillow Home Value Index Single Family
    ZHVISF_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[c]+'_MLPCC', start_date=start_date, end_date=end_date))
    ZHVISF_df.rename(columns = {"Value":"Zillow Home Value Index: Single Family"}, inplace = True)
    # Zillow Home Value Index Condos
    ZHVICO_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[c]+'_MLPCC', start_date=start_date, end_date=end_date))
    ZHVICO_df.rename(columns = {"Value":"Zillow Home Value Index: Condos"}, inplace = True)
    # Zillow Home Value Index Merged
    ZHVI_df = ZHVIAH_df.merge(ZHVISF_df, on=["Date"]).merge(ZHVICO_df, on=["Date"])


    # Zillow Rental Value Index All Homes
    ZRIAH_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[c]+'_MLPCC', start_date=start_date, end_date=end_date))
    ZRIAH_df.rename(columns = {"Value":"Zillow Rental Value Index: All Homes"}, inplace = True)
    # Zillow Rental Value Index Single Family
    ZRISFRR_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[c]+'_MLPCC', start_date=start_date, end_date=end_date))
    ZRISFRR_df.rename(columns = {"Value":"Zillow Rental Value Index: Single Family"}, inplace = True)
    # Zillow Rental Value Index Merged
    ZRVI_df = ZRIAH_df.merge(ZRISFRR_df, on=["Date"])
        
    #merged_df = MLP_df.merge(MRP_df, on=["Date"]).merge(ZHVI_df, on="Date").merge(ZRVI_df, on="Date")
    #all_df = pd.concat(all_df, merged_df, join='inner')
    if m == "M9":
        atl_df = MLP_df.merge(MRP_df, on=["Date"]).merge(ZHVI_df, on="Date").merge(ZRVI_df, on="Date")
    elif m == "M31":
        austin_df = MLP_df.merge(MRP_df, on=["Date"]).merge(ZHVI_df, on="Date").merge(ZRVI_df, on="Date")
    elif m == "M3":
        chicago_df = MLP_df.merge(MRP_df, on=["Date"]).merge(ZHVI_df, on="Date").merge(ZRVI_df, on="Date")
    else:
        nash_df = MLP_df.merge(MRP_df, on=["Date"]).merge(ZHVI_df, on="Date").merge(ZRVI_df, on="Date")
    
    c +=1
# Out:
#             Median Listing Price: All Homes  \
# Date
# 2010-07-31                         175000.0
# 2010-08-31                         174900.0
# 2010-09-30                         169900.0
# 2010-10-31                         169900.0
# 2010-11-30                         168900.0
# 2010-12-31                         159900.0
# 2011-01-31                         157000.0
# 2011-02-28                         155000.0
# 2011-03-31                         154900.0
# 2011-04-30                         150000.0
# 2011-05-31                         153000.0
# 2011-06-30                         153000.0
# 2011-07-31                         150000.0
# 2011-08-31                         150000.0
# 2011-09-30                         149900.0
# 2011-10-31                         147900.0
# 2011-11-30                         142900.0
# 2011-12-31                         139900.0
# 2012-01-31                         139900.0
# 2012-02-29                         139900.0
# 2012-03-31                         144900.0
# 2012-04-30                         145000.0
# 2012-05-31                         149900.0
# 2012-06-30                         150000.0
# 2012-07-31                         155000.0
# 2012-08-31                         159000.0
# 2012-09-30                         159900.0
# 2012-10-31                         164732.5
# 2012-11-30                         165900.0
# 2012-12-31                         168000.0
# ...                                     ...
# 2017-02-28                         242445.0
# 2017-03-31                         250000.0
# 2017-04-30                         259900.0
# 2017-05-31                         263995.0
# 2017-06-30                         265000.0
# 2017-07-31                         264900.0
# 2017-08-31                         261000.0
# 2017-09-30                         263000.0
# 2017-10-31                         265000.0
# 2017-11-30                         265000.0
# 2017-12-31                         265000.0
# 2018-01-31                         269900.0
# 2018-02-28                         274900.0
# 2018-03-31                         279900.0
# 2018-04-30                         287983.5
# 2018-05-31                         290000.0
# 2018-06-30                         290000.0
# 2018-07-31                         284900.0
# 2018-08-31                         279900.0
# 2018-09-30                         281900.0
# 2018-10-31                         279900.0
# 2018-11-30                         279000.0
# 2018-12-31                         278010.0
# 2019-01-31                         275900.0
# 2019-02-28                         279900.0
# 2019-03-31                         288990.0
# 2019-04-30                         293990.0
# 2019-05-31                         294900.0
# 2019-06-30                         293900.0
# 2019-07-31                         289900.0
#
#             Median Listing Price: Single Family  Median Listing Price: Condos
# 2012-11-30                             184990.0                      142900.0
# 2012-12-31                             183900.0                      144762.0
# ...                                         ...                           ...
# 2017-02-28                             314900.0                      244900.0
# 2017-03-31                             324900.0                      249900.0
# 2017-04-30                             339000.0                      264900.0
# 2017-05-31                             343900.0                      291250.0
# 2017-06-30                             342945.0                      285000.0
# 2017-07-31                             338870.5                      280000.0
# 2017-08-31                             335000.0                      289900.0
# 2017-09-30                             334900.0                      279686.0
# 2017-10-31                             339000.0                      274900.0
# 2017-11-30                             340000.0                      279000.0
# 2017-12-31                             339900.0                      269995.0
# 2018-01-31                             335995.0                      269900.0
# 2018-02-28                             342945.0                      275000.0
# 2018-03-31                             339900.0                      278213.5
# 2018-04-30                             345000.0                      289900.0
# 2018-05-31                             339900.0                      289900.0
# 2018-06-30                             339900.0                      289000.0
# 2018-07-31                             335055.0                      280609.5
# 2018-08-31                             330000.0                      272900.0
# 2018-09-30                             332900.0                      275000.0
# 2018-10-31                             330000.0                      275000.0
# 2018-11-30                             329000.0                      279000.0
# 2018-12-31                             329900.0                      271000.0
# 2019-01-31                             329900.0                      269900.0
# 2019-02-28                             329900.0                      269900.0
# 2019-03-31                             330900.0                      269900.0
# 2019-04-30                             339900.0                      274900.0
# 2019-05-31                             339900.0                      272900.0
# 2019-06-30                             339900.0                      269900.0
# 2019-07-31                             339500.0                      269900.0
#
# [109 rows x 3 columns]

# %%
# List of Data Frames
dfs = [atl_df, austin_df, chicago_df, nash_df]
# Concat all Data Frames and Add Title
df_combined = pd.concat([df.rename(columns=lambda x: x.zfill(4)) for df in dfs], keys=['{}'.format(c) for c in city], axis=1)

df_combined.head()
# Out:
#                                    Atlanta  \
#            Median Listing Price: All Homes
# Date
# 2010-07-31                        175000.0
# 2010-08-31                        174900.0
# 2010-09-30                        169900.0
# 2010-10-31                        169900.0
# 2010-11-30                        168900.0
#
#                                                                              \
#            Median Listing Price: Single Family Median Listing Price: Condos
# Date
# 2010-07-31                            179900.0                     149000.0
# 2010-08-31                            179000.0                     144900.0
# 2010-09-30                            175000.0                     140000.0
# 2010-10-31                            173900.0                     139900.0
# 2010-11-30                            170000.0                     139900.0
#
#                                                                   \
#            Median Rental: All Homes Median Rental: Single Family
# Date
# 2010-07-31                 149000.0                     149000.0
# 2010-08-31                 144900.0                     144900.0
# 2010-09-30                 140000.0                     140000.0
# 2010-10-31                 139900.0                     139900.0
# 2010-11-30                 139900.0                     139900.0
#
#                                                                      \
#            Median Rental: Condos Zillow Home Value Index: All Homes
# Date
# 2010-07-31              149000.0                           149000.0
# 2010-08-31              144900.0                           144900.0
# 2010-09-30              140000.0                           140000.0
# 2010-10-31              139900.0                           139900.0
# 2010-11-30              139900.0                           139900.0
#
#                                                    \
#            Zillow Home Value Index: Single Family
# Date
# 2010-07-31                               149000.0
# 2010-08-31                               144900.0
# 2010-09-30                               140000.0
# 2010-10-31                               139900.0
# 2010-11-30                               139900.0
#
#                                             \
#            Zillow Home Value Index: Condos
# Date
# 2010-07-31                        149000.0
# 2010-08-31                        144900.0
# 2010-09-30                        140000.0
# 2010-10-31                        139900.0
# 2010-11-30                        139900.0
#
#                                                  ...  \
#            Zillow Rental Value Index: All Homes  ...
# Date                                             ...
# 2010-07-31                             149000.0  ...
# 2010-08-31                             144900.0  ...
# 2010-09-30                             140000.0  ...
# 2010-10-31                             139900.0  ...
# 2010-11-30                             139900.0  ...
#
#                                      Nashville                               \
#            Median Listing Price: Single Family Median Listing Price: Condos
# Date
# 2010-07-31                            185000.0                     159500.0
# 2010-08-31                            184900.0                     154250.0
# 2010-09-30                            184900.0                     153950.0
# 2010-10-31                            184000.0                     155000.0
# 2010-11-30                            183900.0                     159000.0
#
#                                                                   \
#            Median Rental: All Homes Median Rental: Single Family
# Date
# 2010-07-31                 159500.0                     159500.0
# 2010-08-31                 154250.0                     154250.0
# 2010-09-30                 153950.0                     153950.0
# 2010-10-31                 155000.0                     155000.0
# 2010-11-30                 159000.0                     159000.0
#
#                                                                      \
#            Median Rental: Condos Zillow Home Value Index: All Homes
# Date
# 2010-07-31              159500.0                           159500.0
# 2010-08-31              154250.0                           154250.0
# 2010-09-30              153950.0                           153950.0
# 2010-10-31              155000.0                           155000.0
# 2010-11-30              159000.0                           159000.0
#
#                                                    \
#            Zillow Home Value Index: Single Family
# Date
# 2010-07-31                               159500.0
# 2010-08-31                               154250.0
# 2010-09-30                               153950.0
# 2010-10-31                               155000.0
# 2010-11-30                               159000.0
#
#                                             \
#            Zillow Home Value Index: Condos
# Date
# 2010-07-31                        159500.0
# 2010-08-31                        154250.0
# 2010-09-30                        153950.0
# 2010-10-31                        155000.0
# 2010-11-30                        159000.0
#
#                                                  \
#            Zillow Rental Value Index: All Homes
# Date
# 2010-07-31                             159500.0
# 2010-08-31                             154250.0
# 2010-09-30                             153950.0
# 2010-10-31                             155000.0
# 2010-11-30                             159000.0
#
#
#            Zillow Rental Value Index: Single Family
# Date
# 2010-07-31                                 159500.0
# 2010-08-31                                 154250.0
# 2010-09-30                                 153950.0
# 2010-10-31                                 155000.0
# 2010-11-30                                 159000.0
#
# [5 rows x 44 columns]

# %%
df_combined.tail()

# Push DataFrame to CSV
df_combined.to_csv(r'city.csv')

# %%
# Specify Zillow Indicator we want to graph
indicator = 'MLPAH'

# Specify the county and state we want to generate the map for
metro = 'Chicago'
state = 'IL'

# Start date and end date should be the same
start_date = '2018-06-30'
end_date = '2018-06-30'

# %%
# We are going to fetch the data for each zip code in the county and add that to a single dataframe
def get_city_data(cities, indicator):
    df_array = []
    for city, code in cities.items():
        quandl_db_code = f'ZILLOW/Z{code}_{indicator}'
        try:
            data = quandl.get(quandl_db_code, start_date=start_date, end_date=end_date)
            data.rename(index=str, columns={'Value': city}, inplace=True)
            data.index = pd.to_datetime(data.index, format='%Y/%m/%d')
            df_array.append(data)
        except:
            print(f'Error fetching for: {quandl_db_code}')
    ret = pd.concat(df_array, axis=1)
    return ret

# %%
# Here we are going to figure out what zip codes are in the specified county
# We will also use the logitude / latitude data for plotting

ZIP_CODES = pd.read_csv('zip_code.csv') 
state_df = ZIP_CODES['state'] == state
city_df = ZIP_CODES['city'] == metro
data = ZIP_CODES[city_df & state_df]

# %%
# We will call our function to fetch the data from quandl
# There will be errors for data we cannot retrieve

real_estate_data = get_city_data(data['zip_code'], indicator)
# Out:
# Error fetching for: ZILLOW/Z60602_MLPAH
# Error fetching for: ZILLOW/Z60604_MLPAH
# Error fetching for: ZILLOW/Z60663_MLPAH
# Error fetching for: ZILLOW/Z60664_MLPAH
# Error fetching for: ZILLOW/Z60665_MLPAH
# Error fetching for: ZILLOW/Z60666_MLPAH
# Error fetching for: ZILLOW/Z60667_MLPAH
# Error fetching for: ZILLOW/Z60668_MLPAH
# Error fetching for: ZILLOW/Z60669_MLPAH
# Error fetching for: ZILLOW/Z60670_MLPAH
# Error fetching for: ZILLOW/Z60671_MLPAH
# Error fetching for: ZILLOW/Z60672_MLPAH
# Error fetching for: ZILLOW/Z60673_MLPAH
# Error fetching for: ZILLOW/Z60674_MLPAH
# Error fetching for: ZILLOW/Z60675_MLPAH
# Error fetching for: ZILLOW/Z60677_MLPAH
# Error fetching for: ZILLOW/Z60678_MLPAH
# Error fetching for: ZILLOW/Z60679_MLPAH
# Error fetching for: ZILLOW/Z60680_MLPAH
# Error fetching for: ZILLOW/Z60681_MLPAH
# Error fetching for: ZILLOW/Z60683_MLPAH
# Error fetching for: ZILLOW/Z60684_MLPAH
# Error fetching for: ZILLOW/Z60685_MLPAH
# Error fetching for: ZILLOW/Z60687_MLPAH
# Error fetching for: ZILLOW/Z60690_MLPAH
# Error fetching for: ZILLOW/Z60691_MLPAH
# Error fetching for: ZILLOW/Z60693_MLPAH
# Error fetching for: ZILLOW/Z60694_MLPAH
# Error fetching for: ZILLOW/Z60697_MLPAH
# Error fetching for: ZILLOW/Z60699_MLPAH
# Error fetching for: ZILLOW/Z60701_MLPAH

# %%
# Here we are just doing some transformation and massaging of the data we get back
# If you want more information please run the notebook on your own

transformed_real_estate_data = real_estate_data.transpose()

column_name = f'{indicator} {end_date}'

# %%
transformed_real_estate_data[column_name] = transformed_real_estate_data[end_date].astype('float')

# %%
concat_data = pd.concat([data, transformed_real_estate_data[column_name]], axis=1, sort=True)
print(concat_data)
# Out:
#      zip_code  latitude  longitude     city state  MLPAH 2018-06-30
# 105     60601       NaN        NaN  Chicago    IL               NaN
# 106     60602       NaN        NaN  Chicago    IL               NaN
# 107     60603       NaN        NaN  Chicago    IL          649000.0
# 108     60604       NaN        NaN  Chicago    IL               NaN
# 109     60605       NaN        NaN  Chicago    IL          399250.0
# 110     60606       NaN        NaN  Chicago    IL          398000.0
# 111     60607       NaN        NaN  Chicago    IL          549900.0
# 112     60608       NaN        NaN  Chicago    IL          315000.0
# 113     60609       NaN        NaN  Chicago    IL          215000.0
# 114     60610       NaN        NaN  Chicago    IL          499000.0
# 115     60611       NaN        NaN  Chicago    IL          559000.0
# 116     60612       NaN        NaN  Chicago    IL          309000.0
# 117     60613       NaN        NaN  Chicago    IL          317000.0
# 118     60614       NaN        NaN  Chicago    IL          698000.0
# 119     60615       NaN        NaN  Chicago    IL          219950.0
# 120     60616       NaN        NaN  Chicago    IL          350000.0
# 121     60617       NaN        NaN  Chicago    IL          119900.0
# 122     60618       NaN        NaN  Chicago    IL          495000.0
# 123     60619       NaN        NaN  Chicago    IL          119950.0
# 124     60620       NaN        NaN  Chicago    IL          127416.0
# 125     60621       NaN        NaN  Chicago    IL           40130.0
# 126     60622       NaN        NaN  Chicago    IL          539900.0
# 127     60623       NaN        NaN  Chicago    IL          107400.0
# 128     60624       NaN        NaN  Chicago    IL          125000.0
# 129     60625       NaN        NaN  Chicago    IL          319950.0
# 130     60626       NaN        NaN  Chicago    IL          195000.0
# 131     60628       NaN        NaN  Chicago    IL           85000.0
# 132     60629       NaN        NaN  Chicago    IL          182900.0
# 133     60630       NaN        NaN  Chicago    IL          330000.0
# 134     60631       NaN        NaN  Chicago    IL          375000.0
# ..        ...       ...        ...      ...   ...               ...
# 160     60661       NaN        NaN  Chicago    IL          399500.0
# 161     60663       NaN        NaN  Chicago    IL               NaN
# 162     60664       NaN        NaN  Chicago    IL               NaN
# 163     60665       NaN        NaN  Chicago    IL               NaN
# 164     60666       NaN        NaN  Chicago    IL               NaN
# 165     60667       NaN        NaN  Chicago    IL               NaN
# 166     60668       NaN        NaN  Chicago    IL               NaN
# 167     60669       NaN        NaN  Chicago    IL               NaN
# 168     60670       NaN        NaN  Chicago    IL               NaN
# 169     60671       NaN        NaN  Chicago    IL               NaN
# 170     60672       NaN        NaN  Chicago    IL               NaN
# 171     60673       NaN        NaN  Chicago    IL               NaN
# 172     60674       NaN        NaN  Chicago    IL               NaN
# 173     60675       NaN        NaN  Chicago    IL               NaN
# 174     60677       NaN        NaN  Chicago    IL               NaN
# 175     60678       NaN        NaN  Chicago    IL               NaN
# 176     60679       NaN        NaN  Chicago    IL               NaN
# 177     60680       NaN        NaN  Chicago    IL               NaN
# 178     60681       NaN        NaN  Chicago    IL               NaN
# 179     60683       NaN        NaN  Chicago    IL               NaN
# 180     60684       NaN        NaN  Chicago    IL               NaN
# 181     60685       NaN        NaN  Chicago    IL               NaN
# 182     60687       NaN        NaN  Chicago    IL               NaN
# 183     60690       NaN        NaN  Chicago    IL               NaN
# 184     60691       NaN        NaN  Chicago    IL               NaN
# 185     60693       NaN        NaN  Chicago    IL               NaN
# 186     60694       NaN        NaN  Chicago    IL               NaN
# 187     60697       NaN        NaN  Chicago    IL               NaN
# 188     60699       NaN        NaN  Chicago    IL               NaN
# 189     60701       NaN        NaN  Chicago    IL               NaN
#
# [85 rows x 6 columns]
