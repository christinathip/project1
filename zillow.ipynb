# %%
# Import quandl to retrieve data
# Pandas and matplotlib standard imports for data analysis
import quandl
import pandas as pd

# Put your api key here
quandl.ApiConfig.api_key = 'g3sVyGQgGrx_J1RV9E43'
nash_zip = ['37013', '37027', '37219', '37221', '37027']

greater_metro = ['M9','M31','M33','M3']
city = ['Atlanta', 'Austin', 'Nashville', 'Chicago']


for cities in greater_metro:
    # Median Listing Price All Homes    
    MLPAH_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[0]+'_MLPAH'))
    MLPAH_df.rename(columns = {"Value":"All Homes"}, inplace = True)
 
    # Median Listing Price Single Family Homes
    MLPSF_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[0]+'_MLPSF'))
    MLPSF_df.rename(columns = {"Value":"Single Family"}, inplace = True)
    
    # Median Listing Price Condos
    MLPCC_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[0]+'_MLPCC'))
    MLPCC_df.rename(columns = {"Value":"Condos"}, inplace = True)
    
    MLP_df = MLPAH_df.merge(MLPSF_df, on=["Date"]).merge(MLPCC_df,on=["Date"])
    print(MLP_df)
    # Median Rental Price All Homes
    MRPAH_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[0]+'_MLPCC'))
    MRPAH_df.rename(columns = {"Value":"All Homes"}, inplace = True)
    # Median Rental Price Single Family Homes
    MRPSF_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[0]+'_MLPCC'))
    MRPSF_df.rename(columns = {"Value":"Single Family"}, inplace = True)
    # Median Rental Price Condos
    MRPCC_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[0]+'_MLPCC'))
    MRPCC_df.rename(columns = {"Value":"Condos"}, inplace = True)
    
    MRP_df = MRPAH_df.merge(MRPSF_df, on=["Date"]).merge(MRPCC_df, on=["Date"])
    print(MRP_df)
    # Zillow Home Value Index All Homes
    ZHVIAH_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[0]+'_MLPCC'))
    ZHVIAH_df.rename(columns = {"Value":"All Homes"}, inplace = True)
    # Zillow Home Value Index Single Family
    ZHVISF_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[0]+'_MLPCC'))
    ZHVISF_df.rename(columns = {"Value":"Single Family"}, inplace = True)
    # Zillow Home Value Index Condos
    ZHVICO_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[0]+'_MLPCC'))
    ZHVICO_df.rename(columns = {"Value":"Condos"}, inplace = True)
    
    ZHVI_df = ZHVIAH_df.merge(ZHVISF_df, on=["Date"]).merge(ZHVICO_df, on=["Date"])
    print(ZHVI_df)

    # Zillow Rental Value Index All Homes
    ZRIAH_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[0]+'_MLPCC'))
    ZRIAH_df.rename(columns = {"Value":"All Homes"}, inplace = True)

    # Zillow Rental Value Index Single Family
    ZRISFRR_df = pd.DataFrame(quandl.get('ZILLOW/'+greater_metro[0]+'_MLPCC'))
    ZRISFRR_df.rename(columns = {"Value":"Single Family"}, inplace = True)

    ZRVI_df = ZRIAH_df.merge(ZRISFRR_df, on=["Date"])
    print(ZRVI_df)
# Out:
#             All Homes  Single Family    Condos
# Date
# 2010-01-31   180000.0       185500.0  149900.0
# 2010-02-28   179999.0       185000.0  149900.0
# 2010-03-31   180000.0       185000.0  150000.0
# 2010-04-30   180000.0       188000.0  150000.0
# 2010-05-31   179900.0       185000.0  150000.0
# 2010-06-30   177490.0       179900.0  148000.0
# 2010-07-31   175000.0       179900.0  149000.0
# 2010-08-31   174900.0       179000.0  144900.0
# 2010-09-30   169900.0       175000.0  140000.0
# 2010-10-31   169900.0       173900.0  139900.0
# 2010-11-30   168900.0       170000.0  139900.0
# 2010-12-31   159900.0       164900.0  135000.0
# 2011-01-31   157000.0       159900.0  133700.0
# 2011-02-28   155000.0       159900.0  134000.0
# 2011-03-31   154900.0       158500.0  131900.0
# 2011-04-30   150000.0       154900.0  129900.0
# 2011-05-31   153000.0       156000.0  129900.0
# 2011-06-30   153000.0       157000.0  129900.0
# 2011-07-31   150000.0       155000.0  127700.0
# ...
