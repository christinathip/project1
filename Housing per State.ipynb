# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("../City_Formatted1.csv")
city_df = pd.DataFrame(data)
city_df
# Out:
#            Date       City  Median Listing Price: All Homes  \
# 0     9/30/2014    Atlanta                         213137.5
# 1    10/31/2014    Atlanta                         209900.0
# 2    11/30/2014    Atlanta                         210000.0
# 3    12/31/2014    Atlanta                         205000.0
# 4     1/31/2015    Atlanta                         204975.0
# ..          ...        ...                              ...
# 227   2/28/2019  Nashville                         325000.0
# 228   3/31/2019  Nashville                         325680.5
# 229   4/30/2019  Nashville                         332995.0
# 230   5/31/2019  Nashville                         334050.5
# 231   6/30/2019  Nashville                         334900.0
#
#      Median Listing Price: Single Family  Median Listing Price: Condos  \
# 0                               219800.0                      159000.0
# 1                               215000.0                      159900.0
# ...

# %%
top = 360000
bot = 150000
rtop = 1900
rbot = 1000
xtic = ["9/30/2014","12/31/2014","3/31/2015","6/30/2015","9/30/2015","12/31/2015","3/31/2016","6/30/2016",
        "9/30/2016","12/31/2016","3/31/2017","6/30/2017","9/30/2017","12/31/2017","3/31/2018","6/30/2018",
        "9/30/2018","12/31/2018","3/31/2019","6/30/2019"]

# %%
nash = city_df.loc[city_df["City"] == "Nashville", :]

nash_plot_all, = plt.plot(nash["Date"], nash["Median Listing Price: All Homes"], c="black", label ="All Homes")
nash_plot_single, = plt.plot(nash["Date"], nash["Median Listing Price: Single Family"], c="blue", label ="Single Family")
nash_plot_condo, = plt.plot(nash["Date"], nash["Median Listing Price: Condos"], c="red", label ="Condos")

nash_x = np.arange(0, 58)
nash_y = nash['Median Listing Price: All Homes']

nash_z = np.polyfit(nash_x, nash_y, 1)
nash_p = np.poly1d(nash_z)
plt.plot(nash_x,nash_p(nash_x),"g--")

plt.legend(handles=[nash_plot_all,nash_plot_single,nash_plot_condo],loc="lower right")
plt.grid(axis = "y")
plt.title('Housing Cost: Nashville')
plt.xlabel('Date')
plt.ylabel('Housing Price')
plt.ylim(bot,top)
plt.xticks(xtic,rotation=55,ha="right")
plt.tight_layout()

plt.savefig("housing_nashville.png")

# %%
atl = city_df.loc[city_df["City"] == "Atlanta", :]

atl_plot_all, = plt.plot(atl["Date"], atl["Median Listing Price: All Homes"], c="black", label ="All Homes")
atl_plot_single, = plt.plot(atl["Date"], atl["Median Listing Price: Single Family"], c="blue", label ="Single Family")
atl_plot_condo, = plt.plot(atl["Date"], atl["Median Listing Price: Condos"], c="red", label ="Condos")

atl_x = np.arange(0, 58)
atl_y = atl['Median Listing Price: All Homes']

atl_z = np.polyfit(atl_x, atl_y, 1)
atl_p = np.poly1d(atl_z)
plt.plot(atl_x,atl_p(atl_x),"g--")

plt.legend(handles=[atl_plot_all,atl_plot_single,atl_plot_condo],loc="lower right")
plt.grid(axis = "y")
plt.title('Housing Cost: Atlanta')
plt.xlabel('Date')
plt.ylabel('Housing Price')
plt.ylim(bot,top)
plt.xticks(xtic,rotation=55,ha="right")
plt.tight_layout()

plt.savefig("housing_atlanta.png")

# %%
# Out:
# 58

# %%
aust = city_df.loc[city_df["City"] == "Austin", :]

aust_plot_all, = plt.plot(aust["Date"], aust["Median Listing Price: All Homes"], c="black", label ="All Homes")
aust_plot_single, = plt.plot(aust["Date"], aust["Median Listing Price: Single Family"], c="blue", label ="Single Family")
aust_plot_condo, = plt.plot(aust["Date"], aust["Median Listing Price: Condos"], c="red", label ="Condos")

aust_x = np.arange(0, 58)
aust_y = aust['Median Listing Price: All Homes']

aust_z = np.polyfit(aust_x, aust_y, 1)
aust_p = np.poly1d(aust_z)
plt.plot(aust_x,aust_p(aust_x),"g--")

plt.legend(handles=[aust_plot_all,aust_plot_single,aust_plot_condo],loc="lower right")
plt.grid(axis = "y")
plt.title('Housing Cost: Austin')
plt.xlabel('Date')
plt.ylabel('Housing Price')
plt.ylim(bot,top)
plt.xticks(xtic,rotation=55,ha="right")
plt.tight_layout()

plt.savefig("housing_austin.png")

# %%
chic = city_df.loc[city_df["City"] == "Chicago", :]

chic_plot_all, = plt.plot(chic["Date"], chic["Median Listing Price: All Homes"], c="black", label ="All Homes")
chic_plot_single, = plt.plot(chic["Date"], chic["Median Listing Price: Single Family"], c="blue", label ="Single Family")
chic_plot_condo, = plt.plot(chic["Date"], chic["Median Listing Price: Condos"], c="red", label ="Condos")

chic_x = np.arange(0, 58)
chic_y = chic['Median Listing Price: All Homes']

chic_z = np.polyfit(chic_x, chic_y, 1)
chic_p = np.poly1d(chic_z)
plt.plot(chic_x,chic_p(chic_x),"g--")

plt.legend(handles=[chic_plot_all,chic_plot_single,chic_plot_condo],loc="lower right")
plt.grid(axis = "y")
plt.title('Housing Cost: Chicago')
plt.xlabel('Date')
plt.ylabel('Housing Price')
plt.ylim(bot,top)
plt.xticks(xtic,rotation=55,ha="right")
plt.tight_layout()

plt.savefig("housing_chicago.png")

# %%
nash_plot_all, = plt.plot(nash["Date"], nash["Median Listing Price: All Homes"], c="orange", label ="Nashville")
atl_plot_all, = plt.plot(atl["Date"], atl["Median Listing Price: All Homes"], c="red", label ="Atlanta")
aust_plot_all, = plt.plot(aust["Date"], aust["Median Listing Price: All Homes"], c="black", label ="Austin")
chic_plot_all, = plt.plot(chic["Date"], chic["Median Listing Price: All Homes"], c="blue", label ="Chicago")

plt.legend(handles=[nash_plot_all,atl_plot_all,aust_plot_all,chic_plot_all],loc="lower right")
plt.grid(axis = "y")
plt.title('Housing per City')
plt.xlabel('Date')
plt.ylabel('Housing Price')
plt.ylim(bot,top)
plt.xticks(xtic,rotation=55,ha="right")
plt.tight_layout()

plt.savefig("housing_all.png")

# %%
nash_plot_all_rent, = plt.plot(nash["Date"], nash["Median Rental: All Homes"], c="black", label ="All Homes")
nash_plot_single_rent, = plt.plot(nash["Date"], nash["Median Rental: Single Family"], c="blue", label ="Single Family")
nash_plot_condo_rent, = plt.plot(nash["Date"], nash["Median Rental: Condos"], c="red", label ="Condos")

rnash_x = np.arange(0, 58)
rnash_y = nash['Median Rental: All Homes']

rnash_z = np.polyfit(rnash_x, rnash_y, 1)
rnash_p = np.poly1d(rnash_z)
plt.plot(rnash_x,rnash_p(rnash_x),"g--")

plt.legend(handles=[nash_plot_all_rent,nash_plot_single_rent,nash_plot_condo_rent],loc="lower right")
plt.grid(axis = "y")
plt.title('Rent Cost: Nashville')
plt.xlabel('Date')
plt.ylabel('Rent Price')
plt.ylim(rbot,rtop)
plt.xticks(xtic,rotation=55,ha="right")
plt.tight_layout()

plt.savefig("rent_nashville.png")

# %%
atl_plot_all_rent, = plt.plot(atl["Date"], atl["Median Rental: All Homes"], c="black", label ="All Homes")
atl_plot_single_rent, = plt.plot(atl["Date"], atl["Median Rental: Single Family"], c="blue", label ="Single Family")
atl_plot_condo_rent, = plt.plot(atl["Date"], atl["Median Rental: Condos"], c="red", label ="Condos")

ratl_x = np.arange(0, 58)
ratl_y = atl['Median Rental: All Homes']

ratl_z = np.polyfit(ratl_x, ratl_y, 1)
ratl_p = np.poly1d(ratl_z)
plt.plot(ratl_x,ratl_p(ratl_x),"g--")

plt.legend(handles=[atl_plot_all_rent,atl_plot_single_rent,atl_plot_condo_rent],loc="lower right")
plt.grid(axis = "y")
plt.title('Rent Cost: Atlanta')
plt.xlabel('Date')
plt.ylabel('Rent Price')
plt.ylim(rbot,rtop)
plt.xticks(xtic,rotation=55,ha="right")
plt.tight_layout()

plt.savefig("rent_atlanta.png")

# %%
aust_plot_all_rent, = plt.plot(aust["Date"], aust["Median Rental: All Homes"], c="black", label ="All Homes")
aust_plot_single_rent, = plt.plot(aust["Date"], aust["Median Rental: Single Family"], c="blue", label ="Single Family")
aust_plot_condo_rent, = plt.plot(aust["Date"], aust["Median Rental: Condos"], c="red", label ="Condos")

raust_x = np.arange(0, 58)
raust_y = aust['Median Rental: All Homes']

raust_z = np.polyfit(raust_x, raust_y, 1)
raust_p = np.poly1d(raust_z)
plt.plot(raust_x,raust_p(raust_x),"g--")

plt.legend(handles=[aust_plot_all_rent,aust_plot_single_rent,aust_plot_condo_rent],loc="lower right")
plt.grid(axis = "y")
plt.title('Rent Cost: Austin')
plt.xlabel('Date')
plt.ylabel('Rent Price')
plt.ylim(rbot,rtop)
plt.xticks(xtic,rotation=55,ha="right")
plt.tight_layout()

plt.savefig("rent_austin.png")

# %%
chic_plot_all_rent, = plt.plot(chic["Date"], chic["Median Rental: All Homes"], c="black", label ="All Homes")
chic_plot_single_rent, = plt.plot(chic["Date"], chic["Median Rental: Single Family"], c="blue", label ="Single Family")
chic_plot_condo_rent, = plt.plot(chic["Date"], chic["Median Rental: Condos"], c="red", label ="Condos")

rchic_x = np.arange(0, 58)
rchic_y = chic['Median Rental: All Homes']

rchic_z = np.polyfit(rchic_x, rchic_y, 1)
rchic_p = np.poly1d(rchic_z)
plt.plot(rchic_x,rchic_p(rchic_x),"g--")

plt.legend(handles=[chic_plot_all_rent,chic_plot_single_rent,chic_plot_condo_rent],loc="lower right")
plt.grid(axis = "y")
plt.title('Rent Cost: Chicago')
plt.xlabel('Date')
plt.ylabel('Rent Price')
plt.ylim(rbot,rtop)
plt.xticks(xtic,rotation=55,ha="right")
plt.tight_layout()

plt.savefig("rent_chicago.png")

# %%
nash_plot_all_rent, = plt.plot(nash["Date"], nash["Median Rental: All Homes"], c="orange", label ="Nashville")
atl_plot_all_rent, = plt.plot(atl["Date"], atl["Median Rental: All Homes"], c="red", label ="Atlanta")
aust_plot_all_rent, = plt.plot(aust["Date"], aust["Median Rental: All Homes"], c="black", label ="Austin")
chic_plot_all_rent, = plt.plot(chic["Date"], chic["Median Rental: All Homes"], c="blue", label ="Chicago")

plt.legend(handles=[nash_plot_all_rent,atl_plot_all_rent,aust_plot_all_rent,chic_plot_all_rent],loc="lower right")
plt.grid(axis = "y")
plt.title('Rent per City')
plt.xlabel('Date')
plt.ylabel('Housing Price')
plt.ylim(rbot,rtop)
plt.xticks(xtic,rotation=55,ha="right")
plt.tight_layout()

plt.savefig("rent_all.png")
